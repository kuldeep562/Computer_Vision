# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img=cv2.imread("C:\\Users\\DAXESH MAHERIYA\\Downloads\\kakashi.png")
plt.imshow(img)
plt.show()

# %%
img1=cv2.divide(img,10)
plt.imshow(img1)
plt.show()

# %%
img2=cv2.multiply(img,2)
plt.imshow(img2)
plt.show()

# %%
mask=  np.zeros(img.shape[:2],dtype='uint8')
cv2.rectangle(mask,(150,150),(250,250),255,-1)
ass=cv2.bitwise_and(img,img,mask=mask)
plt.imshow(ass)
plt.show()

# %%
imga=cv2.imread("C:\\Users\\DAXESH MAHERIYA\\Downloads\\home.jpg")
img=cv2.resize(img,(1000,1000))
imga=cv2.resize(imga,(1000,1000))

# %%
das=img+imga
plt.imshow(das)
plt.show()

# %%
dasa=img-imga
plt.imshow(dasa)
plt.show()

# %%
jak=cv2.addWeighted(img,0.3,imga,0.5,0.0)
plt.imshow(jak)
plt.show()

# %%
sad=cv2.imread("C:\\Users\\DAXESH MAHERIYA\\Downloads\\kakashi.png")
sad=cv2.resize(sad,(1000,1000))
centx=w//2
ceny=h//2
h,w=sad.shape[:2]
cv2.circle(sad,(centx,ceny),10,(255,0,255),-1)
plt.imshow(sad)
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data=cv2.imread("C:\\Users\\DAXESH MAHERIYA\\Downloads\\home.jpg",0)
dataa=255-data
# cv2.imshow("imggn",data)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
data=cv2.imread("C:\\Users\\DAXESH MAHERIYA\\Downloads\\home.jpg",0)
dataa=255-data
plt.imshow(data,cmap='gray')
plt.show()
plt.imshow(dataa,cmap='gray')
plt.show()

# %%
assd=cv2.equalizeHist(data)
plt.subplot(121)
plt.title('levo maro')
plt.imshow(data,cmap='gray')
plt.subplot(122)
plt.title('jane chodya')
plt.imshow(assd,cmap='gray')
plt.show()

# %%
plt.subplot(121), plt.hist(data)
plt.subplot(122), plt.hist(assd)
plt.show()

# %%
plt.imshow(data,'gray')
plt.show()

# %%
bata=cv2.resize(data,(1000,1000))
for i in range(h):
    for j in range(w):
        if i<=500 and j<=500:
            if bata[i,j]<100:
               bata[i,j]=40
        if i<=500 and j>=500:
            if bata[i,j]<100:
               bata[i,j]=60
        if i>=500 and j<=500:
            if bata[i,j]<100:
               bata[i,j]=80
        if i>=500 and j>=500:
            if bata[i,j]<100:
               bata[i,j]=100
                
plt.imshow(bata,'gray')
plt.show()

# %%
# cv2.imshow('imf',bata)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
