# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("C:\\Users\\Kuldeep Solanki\\Desktop\\images\\KAKASHI.jpg")
reimage = cv2.resize(image,(1000,1000))
plt.imshow(cv2.cvtColor(reimage,cv2.COLOR_RGB2BGR))
plt.title("Original image")
plt.axis("off")
# Out:
# (-0.5, 999.5, 999.5, -0.5)

# %%
h,w = reimage.shape[:2]
print(h,w)
# Out:
# 1000 1000

# %%
x1 = int(input("Enter the cordinates of the point x1 : "))
y1 = int(input("Enter the cordinates of the point y1 : "))
x2 = int(input("Enter the cordinates of the point x2 : "))
y2 = int(input("Enter the cordinates of the point y2 : "))
x3 = y2-y1
y3 = x2-x1
 
distance = ((x2-x1)**2)+((y2-y1)**2)**0.5
area = 0.5*x3*y3

print("Distance between given points are :",distance,".")
print("Area between guven points are :",area,"pixels.")
# Out:
# Enter the cordinates of the point x1 : 152
# Enter the cordinates of the point y1 : 53
# Enter the cordinates of the point x2 : 64
# Enter the cordinates of the point y2 : 85
# Distance between given points are : 7776.0 .
# Area between guven points are : -1408.0 pixels.

# %%
x1 = int(input("Enter the cordinates of the point x1 : "))
y1 = int(input("Enter the cordinates of the point y1 : "))
x2 = int(input("Enter the cordinates of the point x2 : "))
y2 = int(input("Enter the cordinates of the point y2 : "))
x3 = ((y2-y1)**2)**0.5
y3 = ((x2-x1)**2)**0.5 
d = x3+y3

print("Distance between 4 neighbour points are : ",d)
# Out:
# Enter the cordinates of the point x1 : 15
# Enter the cordinates of the point y1 : 45
# Enter the cordinates of the point x2 : 85
# Enter the cordinates of the point y2 : 65
# Distance between 4 neighbour points are :  90.0

# %%
x1 = int(input("Enter the cordinates of the point x1 : "))
y1 = int(input("Enter the cordinates of the point y1 : "))
x2 = int(input("Enter the cordinates of the point x2 : "))
y2 = int(input("Enter the cordinates of the point y2 : "))
x3 = ((y2-y1)**2)**0.5
y3 = ((x2-x1)**2)**0.5 
if x3>y3:
    d=x3
else:
    d=y3
    
print("Distance between 8 neighbour points are : ",d)
# Out:
# Enter the cordinates of the point x1 : 15
# Enter the cordinates of the point y1 : 45
# Enter the cordinates of the point x2 : 85
# Enter the cordinates of the point y2 : 65
# Distance between 8 neighbour points are :  70.0

# %%
c = 255 // np.log(1*reimage)

log_transformed = c*np.log(1+reimage)
log_transformed = np.uint8(log_transformed)

print("Log tr",log_transformed)
# Out:
# C:\Users\Kuldeep Solanki\AppData\Local\Temp\ipykernel_25324\1647026489.py:1: RuntimeWarning: divide by zero encountered in log
#   c = 255 // np.log(1*reimage)
# C:\Users\Kuldeep Solanki\AppData\Local\Temp\ipykernel_25324\1647026489.py:1: RuntimeWarning: divide by zero encountered in floor_divide
#   c = 255 // np.log(1*reimage)
# Log tr [[[253 254 254]
#   [253 254 254]
#   [252 254 254]
#   ...
#   [253 254 250]
#   [253 255 250]
#   [253 255 251]]
#
#  [[253 254 254]
#   [253 254 254]
#   [252 254 254]
#   ...
#   [253 254 250]
#   [253 254 250]
#   [254 250 251]]
#
#  [[253 254 254]
#   [253 254 254]
#   [253 254 254]
#   ...
#   [252 253 254]
#   [253 254 250]
#   [253 254 250]]
#
#  ...
#
#  [[254 255   2]
#   [  0 254   1]
#   [  0 255   1]
#   ...
#   [  0 252 252]
#   [253 254 254]
#   [255 251 252]]
#
#  [[  0 254   1]
#   [254   0   3]
#   [254   0   1]
#   ...
#   [252 255 254]
#   [  0 254 253]
#   [254 254 252]]
#
#  [[  0   0   5]
#   [  0 254   3]
#   [  0 253   2]
# ...

# %%
c = reimage/255

transferd_data = np.power(c,2)*255
log_transformed_data = np.uint8(log_transformed)

print("Log tr",log_transformed_data)
# Out:
# Log tr [[[253 254 254]
#   [253 254 254]
#   [252 254 254]
#   ...
#   [253 254 250]
#   [253 255 250]
#   [253 255 251]]
#
#  [[253 254 254]
#   [253 254 254]
#   [252 254 254]
#   ...
#   [253 254 250]
#   [253 254 250]
#   [254 250 251]]
#
#  [[253 254 254]
#   [253 254 254]
#   [253 254 254]
#   ...
#   [252 253 254]
#   [253 254 250]
#   [253 254 250]]
#
#  ...
#
#  [[254 255   2]
#   [  0 254   1]
#   [  0 255   1]
#   ...
#   [  0 252 252]
#   [253 254 254]
#   [255 251 252]]
#
#  [[  0 254   1]
#   [254   0   3]
#   [254   0   1]
#   ...
#   [252 255 254]
#   [  0 254 253]
#   [254 254 252]]
#
#  [[  0   0   5]
#   [  0 254   3]
#   [  0 253   2]
#   ...
#   [  0 253 252]
#   [253 252 254]
#   [255 255 254]]]
