# %%
import cv2
import pandas as pd
import matplotlib.pyplot as plt

# %%
image = cv2.imread("C:\\Users\\Kuldeep Solanki\\Desktop\\images\\KAKASHI.jpg")
reimage = cv2.resize(image,(1000,1000))

plt.subplot(121)
plt.title("Original Image")
plt.axis('off')
plt.imshow(cv2.cvtColor(image,cv2.COLOR_RGB2BGR))

plt.subplot(122)
plt.title("Resize Original Image")
plt.axis('off')
plt.imshow(cv2.cvtColor(reimage,cv2.COLOR_RGB2BGR))

# %%
image2 = cv2.imread("C:\\Users\\Kuldeep Solanki\\Desktop\\images\\doctor.jpeg")
reimage2 = cv2.resize(image2,(1000,1000))

plt.subplot(121)
plt.title("Original Image")
plt.axis('off')
plt.imshow(cv2.cvtColor(image2,cv2.COLOR_RGB2BGR))

plt.subplot(122)
plt.title("Resize Image")
plt.axis('off')
plt.imshow(cv2.cvtColor(reimage2,cv2.COLOR_RGB2BGR))

# %%
constant = 2

# %%
def add_img(reimage,reimage2):
    result = cv2.add(reimage,reimage2)
    return result

def sub_img(reimage,reimage2):
    result = cv2.subtract(reimage,reimage2)
    return result

def mul_img(reimage,reimage2):
    result = cv2.multiply(reimage,reimage2)
    return result

def div_img(reimage,constant):
    result = cv2.divide(reimage,reimage2)
    return result

# %%
# plt.imshow(cv2.cvtColor(add_img(reimage,reimage2),cv2.COLOR_RGB2BGR))
# plt.title("Addition of 2 Images")
# plt.axis('off')
# plt.show()

# %%
plt.imshow(cv2.cvtColor(add_img(reimage,reimage2),cv2.COLOR_RGB2BGR))
plt.title("Addition of 2 Images")
plt.axis('off')
plt.show()
