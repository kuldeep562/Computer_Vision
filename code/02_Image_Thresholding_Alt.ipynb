# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img=cv2.imread("C:\\Users\\Kuldeep Solanki\\Desktop\\KAKASHI.jpg",1)
h=int(input("Enter Height :- "))
w=int(input("Enter width :- "))
img1=cv2.resize(img,(h,w))
while(True):
    print("1 for Point in centre")
    print("2 for point in centre & around its 4 neighbour")
    print("3 for point in centre & around its 8 neighbour")
    print("4 for any extra pattern")
    choice=int(input("Enter your choice :- "))
    if choice==1:
        center_x=w//2
        center_y=h//2
        cv2.circle(img1,(center_x,center_y), 3,(0,0,255),-1)
        break
    if choice==2:
        step=int(input("step size around the neighbour :- "))
        center_x=w//2
        center_y=h//2
        h1=center_x
        d1=center_y
        cv2.circle(img1,(center_x,center_y), 3,(0,0,255),-1) 
        cv2.circle(img1,(center_x+step,center_y), 3,(0,0,255),-1)
        cv2.circle(img1,(center_x,center_y+step), 3,(0,0,255),-1)
        cv2.circle(img1,(center_x-step,center_y), 3,(0,0,255),-1)
        cv2.circle(img1,(center_x,center_y-step), 3,(0,0,255),-1)
        break
    if choice==3:
        step=int(input("step size around the neighbour :- "))
        center_x=w//2
        center_y=h//2
        h1=center_x
        d1=center_y
        cv2.circle(img1,(center_x,center_y), 3,(0,0,255),-1) 
        cv2.circle(img1,(center_x+step,center_y), 3,(0,0,255),-1)
        cv2.circle(img1,(center_x,center_y+step), 3,(0,0,255),-1)
        cv2.circle(img1,(center_x-step,center_y), 3,(0,0,255),-1)
        cv2.circle(img1,(center_x,center_y-step), 3,(0,0,255),-1)
        cv2.circle(img1,(center_x+step,center_y-step), 3,(0,0,255),-1)
        cv2.circle(img1,(center_x-step,center_y+step), 3,(0,0,255),-1)
        cv2.circle(img1,(center_x-step,center_y-step), 3,(0,0,255),-1)
        cv2.circle(img1,(center_x+step,center_y+step), 3,(0,0,255),-1)
        break
    if choice==4:
        step=int(input("Step size :- "))
        rang=int(input("Enter range :- "))
        for i in range(rang):
            x=0
            y=0
            for y in range(step):
                for i in range(w):
                    cv2.circle(img1,(x,y), radius=5,color=(0,0,255),thickness=-1) 
                    x=x+step
                    y=y+step
        break
plt.imshow(img1)
# Out:
# Enter Height :- 500
# Enter width :- 500
# 1 for Point in centre
# 2 for point in centre & around its 4 neighbour
# 3 for point in centre & around its 8 neighbour
# 4 for any extra pattern
# Enter your choice :- 3
# step size around the neighbour :- 200

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data=cv2.imread("C:\\Users\\Kuldeep Solanki\\Desktop\\KAKASHI.jpg",1)
data=cv2.resize(data,(1000,1000))
h,w =data.shape[:2]
print(h,w)
X1=int(input("Enter the cordinates of the point x1 = "))
Y1=int(input("Enter the cordinates of the point y1 = "))
X2=int(input("Enter the cordinates of the point x2 = "))
Y2=int(input("Enter the cordinates of the point y2 = "))
Y3=(X2-X1)
X3=(Y2-Y1)
cv2.circle(data, (X1,Y1), 3, (0,0,0), -1)
cv2.circle(data, (X2,Y2), 3, (0,0,0), -1)
# cv2.circle(data, (X1,Y2), 3, (255,0,0), -1)
d=(((X2-X1)**2)+((Y2-Y1)**2))**0.5
area = 0.5*X3*Y3
print("Distance between the given points are ",d,".")
print("Area of the given triangle are ",area,"pixels.")
plt.imshow(data)
# Out:
# 1000 1000
# Enter the cordinates of the point x1 = 200
# Enter the cordinates of the point y1 = 330
# Enter the cordinates of the point x2 = 440
# Enter the cordinates of the point y2 = 550
# Distance between the given points are  325.5764119219941 .
# Area of the given triangle are  26400.0 pixels.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data=cv2.imread("C:\\Users\\Kuldeep Solanki\\Desktop\\KAKASHI.jpg",1)
data=cv2.resize(data,(1000,1000))
h,w =data.shape[:2]
print(h,w)
X1=int(input("Enter the cordinates of the point x1 = "))
Y1=int(input("Enter the cordinates of the point y2 = "))
X2=int(input("Enter the cordinates of the point x1 = "))
Y2=int(input("Enter the cordinates of the point y2 = "))
x3=((X1-X2)**2)**0.5
y3=((Y1-Y2)**2)**0.5
d=x3+y3
print("4 Neighour",d)
# Out:
# 1000 1000
# Enter the cordinates of the point x1 = 200
# Enter the cordinates of the point y2 = 300
# Enter the cordinates of the point x1 = 400
# Enter the cordinates of the point y2 = 500
# 4 Neighour 400.0

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data=cv2.imread("C:\\Users\\Kuldeep Solanki\\Desktop\\KAKASHI.jpg",1)
data=cv2.resize(data,(1000,1000))
h,w =data.shape[:2]
print(h,w)
X1=int(input("Enter the cordinates of the point x1 = "))
Y1=int(input("Enter the cordinates of the point y2 = "))
X2=int(input("Enter the cordinates of the point x1 = "))
Y2=int(input("Enter the cordinates of the point y2 = "))
x3=((X1-X2)**2)**0.5
y3=((Y1-Y2)**2)**0.5
if x3>y3:
    d=x3
else:
    d=y3
print("8 Neighour",d)
# Out:
# 1000 1000
# Enter the cordinates of the point x1 = 100
# Enter the cordinates of the point y2 = 200
# Enter the cordinates of the point x1 = 300
# Enter the cordinates of the point y2 = 400
# 8 Neighour 200.0

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data=cv2.imread("C:\\Users\\Kuldeep Solanki\\Desktop\\KAKASHI.jpg",0)
plt.subplot(121)
plt.imshow(data)

dataa=255-data
plt.subplot(122)
plt.imshow(dataa)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data=cv2.imread("C:\\Users\\Kuldeep Solanki\\Desktop\\KAKASHI.jpg")
data=cv2.resize(data,(1000,1000))
h,w=data.shape[:2]
c = 255 // np.log(1 + np.max(data)) 
log_transformed_data = c * np.log(1 + data)
log_transformed_data = np.uint8(log_transformed_data)
plt.imshow(log_transformed_data)
# Out:
# C:\Users\Kuldeep Solanki\AppData\Local\Temp\ipykernel_16116\148966643.py:10: RuntimeWarning: divide by zero encountered in log
#   log_transformed_data = c * np.log(1 + data)
# C:\Users\Kuldeep Solanki\AppData\Local\Temp\ipykernel_16116\148966643.py:11: RuntimeWarning: invalid value encountered in cast
#   log_transformed_data = np.uint8(log_transformed_data)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data=cv2.imread("C:\\Users\\Kuldeep Solanki\\Desktop\\KAKASHI.jpg",0)
data=cv2.resize(data,(1000,1000))

c =data/255
transformed_image = np.power(c, 2) * 255
log_transformed_data = np.uint8(transformed_image)

plt.imshow(log_transformed_data)
